# %% [markdown]
# # Strings

# %%
print("hello".upper())
print("hello".lower())
print("hello".title())
print("hello".count('l'))
print("hello".replace('o','u'))
# Out:
# HELLO
# hello
# Hello
# 2
# hellu

# %% [markdown]
# # Variables

# %%
message_1 = "I'm learning python"

# %%
 message_1
# Out:
# "I'm learning python"

# %%
message_2 = "i am feeling good"
message_1 + message_2
# Out:
# "I'm learning pythoni am feeling good"

# %%
message_1 +' '+ message_2
# Out:
# "I'm learning python i am feeling good"

# %%
#variable string
f'{message_1} oh ic {message_2}'
# Out:
# "I'm learning python oh ic i am feeling good"

# %% [markdown]
# # Lists

# %%
countries= ['us','pakistan','gaza',0.3,4,'us']
countries
# Out:
# ['us', 'pakistan', 'gaza', 0.3, 4, 'us']

# %%
print(countries[0])
print(countries[-1])
print(countries[-2])
# Out:
# us
# us
# 4

# %%
 #slicing  listname[startindex:stop index]
countries[2:4]
# Out:
# ['gaza', 0.3]

# %%
countries[1:]
# Out:
# ['pakistan', 'gaza', 0.3, 4, 'us']

# %%
countries[:2]
# Out:
# ['us', 'pakistan']

# %% [markdown]
# # adding Elements to list

# %%
#appending
countries.append('canada')
countries[-1]
# Out:
# 'canada'

# %%
countries
# Out:
# ['us', 'pakistan', 'gaza', 0.3, 4, 'us', 'canada']

# %%
countries.insert(0, 'shaheen')
countries[0]
# Out:
# 'shaheen'

# %%
countries
# Out:
# ['shaheen', 'us', 'pakistan', 'gaza', 0.3, 4, 'us', 'canada']

# %%
 countries2=['kashif','kamran']

# %%
countries + countries2
# Out:
# ['shaheen',
#  'us',
#  'pakistan',
#  'gaza',
#  0.3,
#  4,
#  'us',
#  'canada',
#  'kashif',
#  'kamran']

# %%
nested_list= [countries,countries2]

# %%
nested_list
# Out:
# [['shaheen', 'us', 'pakistan', 'gaza', 0.3, 4, 'us', 'canada'],
#  ['kashif', 'kamran']]

# %% [markdown]
# # Removing an element

# %%
countries.remove('us')
countries
# Out:
# ['shaheen', 'pakistan', 'gaza', 0.3, 4, 'us', 'canada']

# %%
countries.remove('us')
countries
# Out:
# ['shaheen', 'pakistan', 'gaza', 0.3, 4, 'canada']

# %%
countries.pop(-1)
# Out:
# 'canada'

# %%
countries
# Out:
# ['shaheen', 'pakistan', 'gaza', 0.3, 4]

# %%
nested_list
# Out:
# [['shaheen', 'pakistan', 'gaza', 0.3, 4], ['kashif', 'kamran']]

# %%
del countries[-1]

# %%
countries
# Out:
# ['shaheen', 'pakistan', 'gaza', 0.3]

# %% [markdown]
# # Sorting list

# %%
numbers=[2,6,8,2,4,1]
numbers.sort()
numbers
# Out:
# [1, 2, 2, 4, 6, 8]

# %%
numbers.sort(reverse=True)
numbers
# Out:
# [8, 6, 4, 2, 2, 1]

# %% [markdown]
# # Update an element

# %%
numbers[0] = 10000
numbers
# Out:
# [10000, 2, 2, 4, 6, 8]

# %% [markdown]
# # Copying a List

# %%
countries[:]
# Out:
# ['shaheen', 'pakistan', 'gaza', 0.3]

# %%
new_list = countries

# %%
new_list
# Out:
# ['shaheen', 'pakistan', 'gaza', 0.3]

# %%
new_list2 = countries.copy()

# %%
new_list2
# Out:
# ['shaheen', 'pakistan', 'gaza', 0.3]

# %% [markdown]
# # Distionaries

# %%
my_dist = {'key1':'value1','key2':'value2'}
my_dist
# Out:
# {'key1': 'value1', 'key2': 'value2'}

# %%
saim = {'Name':"Muhammad saim",'age': 20, 'blood group':'B-positive'}
saim
# Out:
# {'Name': 'Muhammad saim', 'age': 20, 'blood group': 'B-positive'}

# %%
saim.keys()
# Out:
# dict_keys(['Name', 'age', 'blood group'])

# %%
saim.values()
# Out:
# dict_values(['Muhammad saim', 20, 'B-positive'])

# %%
saim.items()
# Out:
# dict_items([('Name', 'Muhammad saim'), ('age', 20), ('blood group', 'B-positive')])

# %%
saim['height']= '7 feet'

# %%
saim
# Out:
# {'Name': 'Muhammad saim',
#  'age': 20,
#  'blood group': 'B-positive',
#  'height': '7 feet'}

# %%
saim.update({'height':'30 feet'})

# %%
saim
# Out:
# {'Name': 'Muhammad saim',
#  'age': 20,
#  'blood group': 'B-positive',
#  'height': '30 feet'}

# %% [markdown]
# # copy of dict

# %%
new_dictionary = saim.copy()
new_dictionary
# Out:
# {'Name': 'Muhammad saim',
#  'age': 20,
#  'blood group': 'B-positive',
#  'height': '6.1 feet'}

# %%
 new_dictionary
# Out:
# {'Name': 'Muhammad saim',
#  'age': 20,
#  'blood group': 'B-positive',
#  'height': '6.1 feet'}

# %%
new_dict = saim

# %%
new_dict
# Out:
# {'Name': 'Muhammad saim',
#  'age': 20,
#  'blood group': 'B-positive',
#  'height': '30 feet'}

# %% [markdown]
# # Removing From Dictionay

# %%
new_dict.pop('Name')
# Out:
# 'Muhammad saim'

# %%
new_dict
# Out:
# {'age': 20, 'blood group': 'B-positive', 'height': '30 feet'}

# %%
del  new_dict['age']

# %%
new_dict
# Out:
# {'blood group': 'B-positive', 'height': '30 feet'}

# %%
new_dict.clear()

# %%
new_dict
# Out:
# {}

# %% [markdown]
# # For loop

# %%
countries= ['us','pakistan','gaza',0.3,4,'us']
for country in countries:
    print(country)
# Out:
# us
# pakistan
# gaza
# 0.3
# 4
# us

# %%
for i,country in enumerate(countries):
    print(i)
    print(country)
# Out:
# 0
# us
# 1
# pakistan
# 2
# gaza
# 3
# 0.3
# 4
# 4
# 5
# us

# %%
new_dictionary
# Out:
# {'Name': 'Muhammad saim',
#  'age': 20,
#  'blood group': 'B-positive',
#  'height': '6.1 feet'}

# %%
for key, value in new_dictionary.items():
    print(key)
    print(value)
# Out:
# Name
# Muhammad saim
# age
# 20
# blood group
# B-positive
# height
# 6.1 feet

# %% [markdown]
# # Built-in Functions

# %%
countries= ['us','pakistan','gaza',0.3,4,'us']
len(countries)
# Out:
# 6

# %%
max([23,43,65,77,32,889,6])
# Out:
# 889

# %%
min([23,43,65,77,32,889,6])
# Out:
# 6

# %%
type(countries)
# Out:
# list

# %%
for i in range(1,10,2):
    print(i)
# Out:
# 1
# 3
# 5
# 7
# 9

# %% [markdown]
# # OS Module

# %%
import os

# %%
os.getcwd()
# Out:
# 'C:\\Users\\Muham\\Desktop\\ai engineering\\python fo datascience'

# %%
os.listdir()
# Out:
# ['.ipynb_checkpoints', 'Python for Datascience.ipynb']

# %%
os.makedirs("love u python")

# %% [markdown]
# # Creating a dataframe from an array

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# ## Option 1

# %%
#creating an array 
data = np.array([[1,4] , [3,4] , [4,5]])

# %%
# creating a dataframe
df=pd.DataFrame(data,index=['row1','row2','row3'],columns=['column1','column2'])

# %%
df
# Out:
#       column1  column2
# row1        1        4
# row2        3        4
# row3        4        5

# %% [markdown]
# ## Option2

# %%
#creating an array with list shape
data = [[1,4] , [3,4] , [4,5]]

# %%
df=pd.DataFrame(data,index=['row1','row2','row3'],columns=['column1','column2'])

# %%
df
# Out:
#       column1  column2
# row1        1        4
# row2        3        4
# row3        4        5

# %% [markdown]
# # Creating Dataframe From a Disctionary

# %%
#list used for this example
states = ['california', 'Texas','Florida','New York']
population =[23233223,3434334,3433433,34334334]

# %%
# sorting lists with a dictionary
dict_states ={'States':states,'Pouplation':population}

# %%
#creating dataframe
df_population=pd.DataFrame(dict_states)

# %%
df_population
# Out:
#        States  Pouplation
# 0  california    23233223
# 1       Texas     3434334
# 2     Florida     3433433
# 3    New York    34334334

# %% [markdown]
# # Creating Dataframe From a CSV File

# %%
#reading from csv file
df_exams=pd.read_csv('StudentsPerformance.csv')

# %%
#show First Five rows in a Datframe
df_exams.head()
# Out:
#    gender race/ethnicity parental level of education         lunch  \
# 0  female        group B           bachelor's degree      standard
# 1  female        group C                some college      standard
# 2  female        group B             master's degree      standard
# 3    male        group A          associate's degree  free/reduced
# 4    male        group C                some college      standard
#
#   test preparation course  math score  reading score  writing score
# 0                    none          72             72             74
# 1               completed          69             90             88
# 2                    none          90             95             93
# 3                    none          47             57             44
# 4                    none          76             78             75

# %%
df_exams
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 0    female        group B           bachelor's degree      standard
# 1    female        group C                some college      standard
# 2    female        group B             master's degree      standard
# 3      male        group A          associate's degree  free/reduced
# 4      male        group C                some college      standard
# ..      ...            ...                         ...           ...
# 995  female        group E             master's degree      standard
# 996    male        group C                 high school  free/reduced
# 997  female        group C                 high school  free/reduced
# 998  female        group D                some college      standard
# 999  female        group D                some college  free/reduced
#
#     test preparation course  math score  reading score  writing score
# ...

# %%
# head method
df_exams.head()
# Out:
#    gender race/ethnicity parental level of education         lunch  \
# 0  female        group B           bachelor's degree      standard
# 1  female        group C                some college      standard
# 2  female        group B             master's degree      standard
# 3    male        group A          associate's degree  free/reduced
# 4    male        group C                some college      standard
#
#   test preparation course  math score  reading score  writing score
# 0                    none          72             72             74
# 1               completed          69             90             88
# 2                    none          90             95             93
# 3                    none          47             57             44
# 4                    none          76             78             75

# %%
# tails method
df_exams.tail()
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 995  female        group E             master's degree      standard
# 996    male        group C                 high school  free/reduced
# 997  female        group C                 high school  free/reduced
# 998  female        group D                some college      standard
# 999  female        group D                some college  free/reduced
#
#     test preparation course  math score  reading score  writing score
# 995               completed          88             99             95
# 996                    none          62             55             55
# 997               completed          59             71             65
# 998               completed          68             78             77
# 999                    none          77             86             86

# %%
#show desired n rows
df_exams.head(10)
# Out:
#    gender race/ethnicity parental level of education         lunch  \
# 0  female        group B           bachelor's degree      standard
# 1  female        group C                some college      standard
# 2  female        group B             master's degree      standard
# 3    male        group A          associate's degree  free/reduced
# 4    male        group C                some college      standard
# 5  female        group B          associate's degree      standard
# 6  female        group B                some college      standard
# 7    male        group B                some college  free/reduced
# 8    male        group D                 high school  free/reduced
# 9  female        group B                 high school  free/reduced
#
#   test preparation course  math score  reading score  writing score
# 0                    none          72             72             74
# 1               completed          69             90             88
# ...

# %%
#show desired n rows
df_exams.tail(10)
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 990    male        group E                 high school  free/reduced
# 991  female        group B            some high school      standard
# 992  female        group D          associate's degree  free/reduced
# 993  female        group D           bachelor's degree  free/reduced
# 994    male        group A                 high school      standard
# 995  female        group E             master's degree      standard
# 996    male        group C                 high school  free/reduced
# 997  female        group C                 high school  free/reduced
# 998  female        group D                some college      standard
# 999  female        group D                some college  free/reduced
#
#     test preparation course  math score  reading score  writing score
# 990               completed          86             81             75
# ...

# %%
df_exams.shape  #(r,c)
# Out:
# (1000, 8)

# %%
#display desired
pd.set_option('display.max_rows',1000)
df_exams
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 0    female        group B           bachelor's degree      standard
# 1    female        group C                some college      standard
# 2    female        group B             master's degree      standard
# 3      male        group A          associate's degree  free/reduced
# 4      male        group C                some college      standard
# 5    female        group B          associate's degree      standard
# 6    female        group B                some college      standard
# 7      male        group B                some college  free/reduced
# 8      male        group D                 high school  free/reduced
# 9    female        group B                 high school  free/reduced
# 10     male        group C          associate's degree      standard
# 11     male        group D          associate's degree      standard
# 12   female        group B                 high school      standard
# ...

# %% [markdown]
# # Attributes of pandas

# %%
df_exams.shape  #(r,c)
# Out:
# (1000, 8)

# %%
df_exams.index   #shows idexes and there steps
# Out:
# RangeIndex(start=0, stop=1000, step=1)

# %%
df_exams.columns
# Out:
# Index(['gender', 'race/ethnicity', 'parental level of education', 'lunch',
#        'test preparation course', 'math score', 'reading score',
#        'writing score'],
#       dtype='object')

# %%
#type of columns
df_exams.dtypes
# Out:
# gender                         object
# race/ethnicity                 object
# parental level of education    object
# lunch                          object
# test preparation course        object
# math score                      int64
# reading score                   int64
# writing score                   int64
# dtype: object

# %% [markdown]
# # Methods

# %%
df_exams.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 8 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   gender                       1000 non-null   object
#  1   race/ethnicity               1000 non-null   object
#  2   parental level of education  1000 non-null   object
#  3   lunch                        1000 non-null   object
#  4   test preparation course      1000 non-null   object
#  5   math score                   1000 non-null   int64
#  6   reading score                1000 non-null   int64
#  7   writing score                1000 non-null   int64
# dtypes: int64(3), object(5)
# memory usage: 62.6+ KB

# %%
#describing basic statistics
df_exams.describe()
# Out:
#        math score  reading score  writing score
# count  1000.00000    1000.000000    1000.000000
# mean     66.08900      69.169000      68.054000
# std      15.16308      14.600192      15.195657
# min       0.00000      17.000000      10.000000
# 25%      57.00000      59.000000      57.750000
# 50%      66.00000      70.000000      69.000000
# 75%      77.00000      79.000000      79.000000
# max     100.00000     100.000000     100.000000

# %% [markdown]
# # Functions

# %%
#obtain len of dataframe   rows only
len(df_exams)
# Out:
# 1000

# %%
#highest index of the dataframe
max(df_exams)
# Out:
# 'writing score'

# %%
max(df_exams.index)
# Out:
# 999

# %%
type(df_exams)
# Out:
# pandas.core.frame.DataFrame

# %%
round(df_exams,2)
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 0    female        group B           bachelor's degree      standard
# 1    female        group C                some college      standard
# 2    female        group B             master's degree      standard
# 3      male        group A          associate's degree  free/reduced
# 4      male        group C                some college      standard
# 5    female        group B          associate's degree      standard
# 6    female        group B                some college      standard
# 7      male        group B                some college  free/reduced
# 8      male        group D                 high school  free/reduced
# 9    female        group B                 high school  free/reduced
# 10     male        group C          associate's degree      standard
# 11     male        group D          associate's degree      standard
# 12   female        group B                 high school      standard
# ...

# %% [markdown]
# # Selecting One Column

# %% [markdown]
# ## Syntax

# %%
 df_exams['gender']
# Out:
# 0      female
# 1      female
# 2      female
# 3        male
# 4        male
#         ...
# 995    female
# 996      male
# 997    female
# 998    female
# 999    female
# Name: gender, Length: 1000, dtype: object

# %%
type( df_exams['gender'])
# Out:
# pandas.core.series.Series

# %%
 print(df_exams['gender'].index)
 print(df_exams['gender'].head())
# Out:
# RangeIndex(start=0, stop=1000, step=1)
# 0    female
# 1    female
# 2    female
# 3      male
# 4      male
# Name: gender, dtype: object

# %% [markdown]
# ## Syntax 2

# %%
df_exams.gender
# Out:
# 0      female
# 1      female
# 2      female
# 3        male
# 4        male
#         ...
# 995    female
# 996      male
# 997    female
# 998    female
# 999    female
# Name: gender, Length: 1000, dtype: object

# %%
# Selecting two columns'
df_exams[['gender','math score']]
# Out:
#      gender  math score
# 0    female          72
# 1    female          69
# 2    female          90
# 3      male          47
# 4      male          76
# ..      ...         ...
# 995  female          88
# 996    male          62
# 997  female          59
# 998  female          68
# 999  female          77
#
# [1000 rows x 2 columns]

# %%
type(df_exams[['gender','math score']])
# Out:
# pandas.core.frame.DataFrame

# %% [markdown]
# # Adding a new column

# %%
df_exams['english score'] = 70

# %%
df_exams
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 0    female        group B           bachelor's degree      standard
# 1    female        group C                some college      standard
# 2    female        group B             master's degree      standard
# 3      male        group A          associate's degree  free/reduced
# 4      male        group C                some college      standard
# ..      ...            ...                         ...           ...
# 995  female        group E             master's degree      standard
# 996    male        group C                 high school  free/reduced
# 997  female        group C                 high school  free/reduced
# 998  female        group D                some college      standard
# 999  female        group D                some college  free/reduced
#
#     test preparation course  math score  reading score  writing score  \
# ...

# %% [markdown]
# # Adding using an array

# %%
#using numpy
language = np.arange(0,1000)

# %%
len(language)
# Out:
# 1000

# %%
df_exams['language']= language
df_exams
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 0    female        group B           bachelor's degree      standard
# 1    female        group C                some college      standard
# 2    female        group B             master's degree      standard
# 3      male        group A          associate's degree  free/reduced
# 4      male        group C                some college      standard
# ..      ...            ...                         ...           ...
# 995  female        group E             master's degree      standard
# 996    male        group C                 high school  free/reduced
# 997  female        group C                 high school  free/reduced
# 998  female        group D                some college      standard
# 999  female        group D                some college  free/reduced
#
#     test preparation course  math score  reading score  writing score  \
# ...

# %%
# randon number

# %%
int_language_score = np.random.randint(1,100,size= 1000)

# %%
min(int_language_score)
# Out:
# 1

# %%
max(int_language_score)
# Out:
# 99

# %%
df_exams['int_language_score']= int_language_score
df_exams
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 0    female        group B           bachelor's degree      standard
# 1    female        group C                some college      standard
# 2    female        group B             master's degree      standard
# 3      male        group A          associate's degree  free/reduced
# 4      male        group C                some college      standard
# ..      ...            ...                         ...           ...
# 995  female        group E             master's degree      standard
# 996    male        group C                 high school  free/reduced
# 997  female        group C                 high school  free/reduced
# 998  female        group D                some college      standard
# 999  female        group D                some college  free/reduced
#
#     test preparation course  math score  reading score  writing score  \
# ...

# %%
np.random.uniform(1,100, size =1000)
# Out:
# array([55.95627663, 57.81648017, 86.41191745,  9.26541768, 14.87946812,
#         7.08237551, 24.28026529, 18.65157089, 79.09127296, 66.46673021,
#        20.13973671, 61.06882243, 36.2382638 , 76.61950473, 24.80513815,
#        49.45352391,  4.30439047, 38.54556391, 24.40537963, 89.88149564,
#        26.9603124 ,  7.18364088,  8.0908839 , 29.8758087 ,  4.59137569,
#        25.59538266, 63.59695977, 26.15344985, 33.23166628, 96.71574252,
#        84.24319139, 95.51428322, 29.21468817, 64.17764136, 13.72988458,
#        59.00653506, 75.47002994, 83.71481878,  7.77830148, 70.65439904,
#        61.88465659, 73.85011671, 57.25746439, 10.41623636, 23.77956223,
#        91.37668854, 89.66165583, 18.85920762, 47.84937833, 43.93442732,
#        83.33133266, 29.66482951, 33.6878463 , 13.58728336, 47.6251448 ,
#         8.79613139, 88.17311032, 38.4330153 , 46.37722362, 76.98898104,
#        59.48618048, 70.25617099, 36.79509074, 82.30482597, 57.40313579,
# ...

# %% [markdown]
#  # Assign method

# %%
import numpy as np
import pandas as pd
#creation of random numbers
score1 = np.random.randint(1,100,size = 1000)
score2 = np.random.randint(1,100,size = 1000)

# %%
series1 =pd.Series(score1, index=np.arange(0,1000))
series2 =pd.Series(score1, index=np.arange(0,1000))

# %%
df_exams=pd.read_csv('StudentsPerformance.csv')
df_exams = df_exams.assign(score1 = series1, score2 = series2)

# %%
df_exams
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 0    female        group B           bachelor's degree      standard
# 1    female        group C                some college      standard
# 2    female        group B             master's degree      standard
# 3      male        group A          associate's degree  free/reduced
# 4      male        group C                some college      standard
# ..      ...            ...                         ...           ...
# 995  female        group E             master's degree      standard
# 996    male        group C                 high school  free/reduced
# 997  female        group C                 high school  free/reduced
# 998  female        group D                some college      standard
# 999  female        group D                some college  free/reduced
#
#     test preparation course  math score  reading score  writing score  score1  \
# ...

# %% [markdown]
#  # Insert Method

# %%
#insert a new column at a specific position or index
df_exams=pd.read_csv('StudentsPerformance.csv')
df_exams.insert(1,'test',series1)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 2
#       1 #insert a new column at a specific position or index
# ----> 2 df_exams=pd.read_csv('StudentsPerformance.csv')
#       3 df_exams.insert(1,'test',series1)
#
# NameError: name 'pd' is not defined

# %%
df_exams
# Out:
#      gender  test race/ethnicity parental level of education         lunch  \
# 0    female    17        group B           bachelor's degree      standard
# 1    female    36        group C                some college      standard
# 2    female    47        group B             master's degree      standard
# 3      male    61        group A          associate's degree  free/reduced
# 4      male    34        group C                some college      standard
# ..      ...   ...            ...                         ...           ...
# 995  female    36        group E             master's degree      standard
# 996    male    23        group C                 high school  free/reduced
# 997  female    60        group C                 high school  free/reduced
# 998  female     4        group D                some college      standard
# 999  female    41        group D                some college  free/reduced
#
# ...

# %% [markdown]
# # Average calculation

# %%
import numpy as np
import pandas as pd
df_exams=pd.read_csv('StudentsPerformance.csv')
df_exams['average'] = df_exams['math score'] + df_exams['reading score'] + df_exams['writing score']/3

# %%
df_exams
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 0    female        group B           bachelor's degree      standard
# 1    female        group C                some college      standard
# 2    female        group B             master's degree      standard
# 3      male        group A          associate's degree  free/reduced
# 4      male        group C                some college      standard
# ..      ...            ...                         ...           ...
# 995  female        group E             master's degree      standard
# 996    male        group C                 high school  free/reduced
# 997  female        group C                 high school  free/reduced
# 998  female        group D                some college      standard
# 999  female        group D                some college  free/reduced
#
#     test preparation course  math score  reading score  writing score  \
# ...

# %% [markdown]
# # Counting By catagory

# %%
df_exams['gender'].value_counts()
# Out:
# gender
# female    518
# male      482
# Name: count, dtype: int64

# %% [markdown]
# # Relative frequency
# #### divide all the values by the sum of values

# %%
df_exams['gender'].value_counts(normalize= True)
# Out:
# gender
# female    0.518
# male      0.482
# Name: proportion, dtype: float64

# %% [markdown]
# # Sort a DataFrame

# %%
#creates only a copy
df_exams.sort_values('math score',ascending=False)
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 962  female        group E          associate's degree      standard
# 625    male        group D                some college      standard
# 458  female        group E           bachelor's degree      standard
# 623    male        group A                some college      standard
# 451  female        group E                some college      standard
# ..      ...            ...                         ...           ...
# 145  female        group C                some college  free/reduced
# 787  female        group B                some college      standard
# 17   female        group B            some high school  free/reduced
# 980  female        group B                 high school  free/reduced
# 59   female        group C            some high school  free/reduced
#
#     test preparation course  math score  reading score  writing score  \
# ...

# %%
#creates only a copy
df_exams.sort_values(['math score','reading score'],ascending=False)
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 149    male        group E          associate's degree  free/reduced
# 458  female        group E           bachelor's degree      standard
# 916    male        group E           bachelor's degree      standard
# 962  female        group E          associate's degree      standard
# 625    male        group D                some college      standard
# ..      ...            ...                         ...           ...
# 145  female        group C                some college  free/reduced
# 787  female        group B                some college      standard
# 17   female        group B            some high school  free/reduced
# 980  female        group B                 high school  free/reduced
# 59   female        group C            some high school  free/reduced
#
#     test preparation course  math score  reading score  writing score  \
# ...

# %%
df_exams
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 0    female        group B           bachelor's degree      standard
# 1    female        group C                some college      standard
# 2    female        group B             master's degree      standard
# 3      male        group A          associate's degree  free/reduced
# 4      male        group C                some college      standard
# ..      ...            ...                         ...           ...
# 995  female        group E             master's degree      standard
# 996    male        group C                 high school  free/reduced
# 997  female        group C                 high school  free/reduced
# 998  female        group D                some college      standard
# 999  female        group D                some college  free/reduced
#
#     test preparation course  math score  reading score  writing score  \
# ...

# %%
# for deep copy
df_exams.sort_values(['math score','reading score'],ascending=False, inplace= True)

# %%
df_exams
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 149    male        group E          associate's degree  free/reduced
# 458  female        group E           bachelor's degree      standard
# 916    male        group E           bachelor's degree      standard
# 962  female        group E          associate's degree      standard
# 625    male        group D                some college      standard
# ..      ...            ...                         ...           ...
# 145  female        group C                some college  free/reduced
# 787  female        group B                some college      standard
# 17   female        group B            some high school  free/reduced
# 980  female        group B                 high school  free/reduced
# 59   female        group C            some high school  free/reduced
#
#     test preparation course  math score  reading score  writing score  \
# ...

# %%
df_exams.sort_values('race/ethnicity',ascending= True )
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 741  female        group A          associate's degree  free/reduced
# 151    male        group A           bachelor's degree      standard
# 811    male        group A                 high school  free/reduced
# 112    male        group A          associate's degree      standard
# 25     male        group A             master's degree  free/reduced
# ..      ...            ...                         ...           ...
# 751    male        group E                some college      standard
# 915  female        group E                some college      standard
# 592    male        group E           bachelor's degree      standard
# 479    male        group E          associate's degree      standard
# 517  female        group E                some college      standard
#
#     test preparation course  math score  reading score  writing score  \
# ...

# %%
df_exams.sort_values('race/ethnicity',ascending= True, key = lambda col:col.str.lower())
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 741  female        group A          associate's degree  free/reduced
# 151    male        group A           bachelor's degree      standard
# 811    male        group A                 high school  free/reduced
# 112    male        group A          associate's degree      standard
# 25     male        group A             master's degree  free/reduced
# ..      ...            ...                         ...           ...
# 751    male        group E                some college      standard
# 915  female        group E                some college      standard
# 592    male        group E           bachelor's degree      standard
# 479    male        group E          associate's degree      standard
# 517  female        group E                some college      standard
#
#     test preparation course  math score  reading score  writing score  \
# ...

# %% [markdown]
# # Shuffel method

# %%
import numpy as np
import random

# %%
new_index = np.arange(0,1000)

# %%
random.shuffle(new_index)

# %%
df_exams['new_index']= new_index
df_exams
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 0    female        group B           bachelor's degree      standard
# 1    female        group C                some college      standard
# 2    female        group B             master's degree      standard
# 3      male        group A          associate's degree  free/reduced
# 4      male        group C                some college      standard
# ..      ...            ...                         ...           ...
# 995  female        group E             master's degree      standard
# 996    male        group C                 high school  free/reduced
# 997  female        group C                 high school  free/reduced
# 998  female        group D                some college      standard
# 999  female        group D                some college  free/reduced
#
#     test preparation course  math score  reading score  writing score  \
# ...

# %%
# set index
df_exams.set_index('new_index',inplace= True)

# %%
df_exams
# Out:
#            gender race/ethnicity parental level of education         lunch  \
# new_index
# 242        female        group B           bachelor's degree      standard
# 127        female        group C                some college      standard
# 359        female        group B             master's degree      standard
# 119          male        group A          associate's degree  free/reduced
# 288          male        group C                some college      standard
# ...           ...            ...                         ...           ...
# 850        female        group E             master's degree      standard
# 995          male        group C                 high school  free/reduced
# 700        female        group C                 high school  free/reduced
# 723        female        group D                some college      standard
# 247        female        group D                some college  free/reduced
#
# ...

# %%
df_exams.sort_index(inplace= True)

# %%
df_exams
# Out:
#            gender race/ethnicity parental level of education         lunch  \
# new_index
# 0            male        group A          associate's degree      standard
# 1          female        group C          associate's degree      standard
# 2            male        group D            some high school      standard
# 3            male        group A                some college      standard
# 4          female        group C           bachelor's degree      standard
# ...           ...            ...                         ...           ...
# 995          male        group C                 high school  free/reduced
# 996        female        group E             master's degree      standard
# 997          male        group C            some high school      standard
# 998          male        group D                some college      standard
# 999        female        group B            some high school      standard
#
# ...

# %%
df_exams.sort_index(ascending=False,inplace= True)

# %%
df_exams
# Out:
#            gender race/ethnicity parental level of education         lunch  \
# new_index
# 999        female        group B            some high school      standard
# 998          male        group D                some college      standard
# 997          male        group C            some high school      standard
# 996        female        group E             master's degree      standard
# 995          male        group C                 high school  free/reduced
# ...           ...            ...                         ...           ...
# 4          female        group C           bachelor's degree      standard
# 3            male        group A                some college      standard
# 2            male        group D            some high school      standard
# 1          female        group C          associate's degree      standard
# 0            male        group A          associate's degree      standard
#
# ...

# %% [markdown]
# # Rename Column

# %%
df_exams.rename(columns={'gender':'Gender'},inplace= True)

# %%
df_exams
# Out:
#            Gender race/ethnicity parental level of education         lunch  \
# new_index
# 999        female        group B            some high school      standard
# 998          male        group D                some college      standard
# 997          male        group C            some high school      standard
# 996        female        group E             master's degree      standard
# 995          male        group C                 high school  free/reduced
# ...           ...            ...                         ...           ...
# 4          female        group C           bachelor's degree      standard
# 3            male        group A                some college      standard
# 2            male        group D            some high school      standard
# 1          female        group C          associate's degree      standard
# 0            male        group A          associate's degree      standard
#
# ...
